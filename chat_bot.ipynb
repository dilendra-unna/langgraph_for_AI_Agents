# %%
import os 
from typing import TypedDict, Literal
from dotenv import load_dotenv
from langchain_ollama import ChatOllama
from langgraph.graph import StateGraph,START ,END
from pydantic import BaseModel ,Field

# %%
llm = ChatOllama(model ='llama3.1',
                 temperature=1.2)

# %%
result = llm.invoke("what is machine learning give me 5 bullet points")

# %%
result.content
# Out:
# 'Here are five key points that summarize what Machine Learning (ML) is:\n\n• **Automated pattern recognition**: Machine learning enables computers to automatically recognize patterns in data, without being explicitly programmed. This means that ML algorithms can identify relationships and trends within the data on their own.\n\n• **Data-driven decision-making**: ML uses data as input to make predictions or take actions, rather than relying on pre-defined rules or manual calculations. The goal is to use the learned patterns to improve performance, accuracy, or efficiency in a particular task or application.\n\n• **Training and adaptation**: Machine learning involves training algorithms on a dataset of examples, which allows them to learn from experience and adapt to new situations. This enables the ML model to continually improve its predictions or decisions over time, as it is exposed to more data.\n\n• **No explicit programming**: Unlike traditional computer programs, ML algorithms do not require explicit instructions for every possible scenario. Instead, they use statistical methods to learn from examples and generate rules that can be applied broadly.\n\n• **Continuous improvement**: Machine learning models are designed to continuously improve over time through retraining on new data, which allows them to refine their performance and address issues such as bias or errors in the initial model. This iterative process is a key aspect of ML, enabling the development of accurate and effective predictive models.'
